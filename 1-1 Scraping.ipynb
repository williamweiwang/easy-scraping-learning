# %%
from urllib.request import urlopen
html = urlopen(
"https://www.youtube.com/watch?v=7B-nvXUJGQs&list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&index=2"
).read().decode('utf-8')

print(html)
# Out:
# <!DOCTYPE html><html lang="zh-TW" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}</style><script name="www-roboto" >if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "中");document.fonts.load("500 10pt Roboto", "中");}</script><script >var ytcsi = {gt: function(n) {n = (n || '') + 'data_';return ytcsi[n] || (ytcsi[n] = {tick: {},info: {}});},now: window.performance && window.performance.timing &&window.performance.now ? function() {return window.performance.timing.navigationStart + window.performance.now();} : function() {return (new Date()).getTime();},tick: function(l, t, n) {ticks = ytcsi.gt(n).tick;var v = t || ytcsi.now();if (ticks[l]) {ticks['_' + l] = (ticks['_' + l] || [ticks[l]]);ticks['_' + l].push(v);}ticks[l] = v;},info: function(k, v, n) {ytcsi.gt(n).info[k] = v;},setStart: function(s, t, n) {ytcsi.info('yt_sts', s, n);ytcsi.tick('_start', t, n);}};(function(w, d) {ytcsi.setStart('dhs', w.performance ? w.performance.timing.responseStart : null);var isPrerender = (d.visibilityState || d.webkitVisibilityState) == 'prerender';var vName = (!d.visibilityState && d.webkitVisibilityState)? 'webkitvisibilitychange' : 'visibilitychange';if (isPrerender) {ytcsi.info('prerender', 1);var startTick = function() {ytcsi.setStart('dhs');d.removeEventListener(vName, startTick);};d.addEventListener(vName, startTick, false);}if (d.addEventListener) {d.addEventListener(vName, function() {ytcsi.tick('vc');}, false);}var slt = function(el, t) {setTimeout(function() {var n = ytcsi.now();el.loadTime = n;if (el.slt) {el.slt();}}, t);};w.__ytRIL = function(el) {if (!el.getAttribute('data-thumb')) {if (w.requestAnimationFrame) {w.requestAnimationFrame(function() {slt(el, 0);});} else {slt(el, 16);}}};})(window, document);</script><script >var ytcfg = {d: function() {return (window.yt && yt.config_) || ytcfg.data_ || (ytcfg.data_ = {});},get: function(k, o) {return (k in ytcfg.d()) ? ytcfg.d()[k] : o;},set: function() {var a = arguments;if (a.length > 1) {ytcfg.d()[a[0]] = a[1];} else {for (var k in a[0]) {ytcfg.d()[k] = a[0][k];}}}};</script>  <script>ytcfg.set("ROOT_VE_TYPE", 3832);ytcfg.set("EVENT_ID", "Z7HEWsCONYbk4wLD64PADw");</script>
#   <script >ytcfg.set("LACT", null);</script>
#
#
#
#
#
#   <script>
#         (function(){var b={a:"content-snap-width-1",b:"content-snap-width-2",c:"content-snap-width-3"};function f(){var a=[],c;for(c in b)a.push(b[c]);return a}
# function h(a){var c=f().concat(["guide-pinned","show-guide"]),e=c.length,g=[];a.replace(/\S+/g,function(a){for(var d=0;d<e;d++)if(a==c[d])return;g.push(a)});
# return g}
# ;function k(a,c,e){var g=document.getElementsByTagName("html")[0],d=h(g.className);a&&1251<=(window.innerWidth||document.documentElement.clientWidth)&&(d.push("guide-pinned"),c&&d.push("show-guide"));e&&(e=(window.innerWidth||document.documentElement.clientWidth)-21-50,1251<=(window.innerWidth||document.documentElement.clientWidth)&&a&&c&&(e-=230),d.push(1262<=e?"content-snap-width-3":1056<=e?"content-snap-width-2":"content-snap-width-1"));g.className=d.join(" ")}
# var l=["yt","www","masthead","sizing","runBeforeBodyIsReady"],m=this;l[0]in m||"undefined"==typeof m.execScript||m.execScript("var "+l[0]);for(var n;l.length&&(n=l.shift());)l.length||void 0===k?m[n]&&m[n]!==Object.prototype[n]?m=m[n]:m=m[n]={}:m[n]=k;}).call(this);
#
#       try {window.ytbuffer = {};ytbuffer.handleClick = function(e) {var element = e.target || e.srcElement;while (element.parentElement) {if (/(^| )yt-can-buffer( |$)/.test(element.className)) {window.ytbuffer = {bufferedClick: e};element.className += ' yt-is-buffered';break;}element = element.parentElement;}};if (document.addEventListener) {document.addEventListener('click', ytbuffer.handleClick);} else {document.attachEvent('onclick', ytbuffer.handleClick);}} catch(e) {}
#
#     yt.www.masthead.sizing.runBeforeBodyIsReady(false,false,true);
#   </script>
#
#       <script src="/yts/jsbin/scheduler-vflmFCrpA/scheduler.js" type="text/javascript" name="scheduler/scheduler" ></script>
#
#
#     <script >var ytimg = {};ytimg.count = 1;ytimg.preload = function(src) {var img = new Image();var count = ++ytimg.count;ytimg[count] = img;img.onload = img.onerror = function() {delete ytimg[count];};img.src = src;};</script>
#
#
#       <script src="/yts/jsbin/www-pagead-id-vfla_fkeg/www-pagead-id.js" type="text/javascript" name="www-pagead-id/www-pagead-id"  async></script>
#
#       <script src="/yts/jsbin/player-vflENcx6t/zh_TW/base.js"  name="player/base" ></script>
#
#
#
#   <link rel="stylesheet" href="/yts/cssbin/www-core-vflx7D8A3.css" name="www-core">
#       <link rel="stylesheet" href="/yts/cssbin/player-vflxUKlL0/www-player.css" name="player/www-player">
#
#   <link rel="stylesheet" href="/yts/cssbin/www-pageframe-vflBE-miK.css" name="www-pageframe">
#       <script>ytimg.preload("https:\/\/r2---sn-3cgv-un5d.googlevideo.com\/generate_204?conn2");ytimg.preload("https:\/\/r2---sn-3cgv-un5d.googlevideo.com\/generate_204");</script>
#
# <title>#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial) - YouTube</title><link rel="canonical" href="https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2"><link rel="alternate" media="handheld" href="https://m.youtube.com/watch?v=7B-nvXUJGQs"><link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.youtube.com/watch?v=7B-nvXUJGQs">      <meta name="title" content="#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)">
#
#         <meta name="description" content="学习爬虫, 首先要懂的是网页. 支撑起各种光鲜亮丽的网页的不是别的, 全都是一些代码. 这种代码我们称之为 HTML... Code: https://github.com/MorvanZhou/easy-scraping-tutorial &quot;莫烦Python&quot; 爬虫 教学目录: https://morvanzh...">
#
#       <meta name="keywords" content="python, 教程, 学习, 实战, 实践, 机器学习, 爬虫, scraping, scraper, crawl, spider">
#
# <link rel="manifest" href="/manifest.json"><link rel="shortlink" href="https://youtu.be/7B-nvXUJGQs?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk"><link rel="search" type="application/opensearchdescription+xml" href="https://www.youtube.com/opensearch?locale=zh_TW" title="YouTube 影片搜尋"><link rel="shortcut icon" href="https://s.ytimg.com/yts/img/favicon-vfl8qSV2F.ico" type="image/x-icon">     <link rel="icon" href="/yts/img/favicon_32-vflOogEID.png" sizes="32x32"><link rel="icon" href="/yts/img/favicon_48-vflVjB_Qk.png" sizes="48x48"><link rel="icon" href="/yts/img/favicon_96-vflW9Ec0w.png" sizes="96x96"><link rel="icon" href="/yts/img/favicon_144-vfliLAfaB.png" sizes="144x144"><meta name="theme-color" content="#ff0000">        <link rel="alternate" href="android-app://com.google.android.youtube/http/www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2">
#     <link rel="alternate" href="ios-app://544007664/vnd.youtube/www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2">
#
#       <link rel="alternate" type="application/json+oembed" href="http://www.youtube.com/oembed?url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D7B-nvXUJGQs%26list%3DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%26index%3D2&amp;format=json" title="#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)">
#   <link rel="alternate" type="text/xml+oembed" href="http://www.youtube.com/oembed?url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D7B-nvXUJGQs%26list%3DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%26index%3D2&amp;format=xml" title="#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)">
#
#           <meta name="robots" content="noindex">
#     <meta property="og:site_name" content="YouTube">
#       <meta property="og:url" content="https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2">
#     <meta property="og:title" content="#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)">
#     <meta property="og:image" content="https://i.ytimg.com/vi/7B-nvXUJGQs/maxresdefault.jpg">
#
#       <meta property="og:description" content="学习爬虫, 首先要懂的是网页. 支撑起各种光鲜亮丽的网页的不是别的, 全都是一些代码. 这种代码我们称之为 HTML... Code: https://github.com/MorvanZhou/easy-scraping-tutorial &quot;莫烦Python&quot; 爬虫 教学目录: https://morvanzh...">
#
#     <meta property="al:ios:app_store_id" content="544007664">
#     <meta property="al:ios:app_name" content="YouTube">
#       <meta property="al:ios:url" content="vnd.youtube://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2&amp;feature=applinks">
#
#       <meta property="al:android:url" content="vnd.youtube://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2&amp;feature=applinks">
#     <meta property="al:android:app_name" content="YouTube">
#     <meta property="al:android:package" content="com.google.android.youtube">
#     <meta property="al:web:url" content="https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2&amp;feature=applinks">
#
#     <meta property="og:type" content="video.other">
#         <meta property="og:video:url" content="https://www.youtube.com/embed/7B-nvXUJGQs?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk">
#         <meta property="og:video:secure_url" content="https://www.youtube.com/embed/7B-nvXUJGQs?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk">
#         <meta property="og:video:type" content="text/html">
#         <meta property="og:video:width" content="1280">
#         <meta property="og:video:height" content="720">
#         <meta property="og:video:url" content="http://www.youtube.com/v/7B-nvXUJGQs?version=3&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk">
#         <meta property="og:video:secure_url" content="https://www.youtube.com/v/7B-nvXUJGQs?version=3&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk">
#         <meta property="og:video:type" content="application/x-shockwave-flash">
#         <meta property="og:video:width" content="1280">
#         <meta property="og:video:height" content="720">
#
#         <meta property="og:video:tag" content="python">
#         <meta property="og:video:tag" content="教程">
#         <meta property="og:video:tag" content="学习">
#         <meta property="og:video:tag" content="实战">
#         <meta property="og:video:tag" content="实践">
#         <meta property="og:video:tag" content="机器学习">
#         <meta property="og:video:tag" content="爬虫">
#         <meta property="og:video:tag" content="scraping">
#         <meta property="og:video:tag" content="scraper">
#         <meta property="og:video:tag" content="crawl">
#         <meta property="og:video:tag" content="spider">
#
#     <meta property="fb:app_id" content="87741124305">
#
#         <meta name="twitter:card" content="player">
#     <meta name="twitter:site" content="@youtube">
#     <meta name="twitter:url" content="https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2">
#     <meta name="twitter:title" content="#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)">
#     <meta name="twitter:description" content="学习爬虫, 首先要懂的是网页. 支撑起各种光鲜亮丽的网页的不是别的, 全都是一些代码. 这种代码我们称之为 HTML... Code: https://github.com/MorvanZhou/easy-scraping-tutorial &quot;莫烦Python&quot; 爬虫 教学目录: https://morvanzh...">
#     <meta name="twitter:image" content="https://i.ytimg.com/vi/7B-nvXUJGQs/maxresdefault.jpg">
#     <meta name="twitter:app:name:iphone" content="YouTube">
#     <meta name="twitter:app:id:iphone" content="544007664">
#     <meta name="twitter:app:name:ipad" content="YouTube">
#     <meta name="twitter:app:id:ipad" content="544007664">
#       <meta name="twitter:app:url:iphone" content="vnd.youtube://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2&amp;feature=applinks">
#       <meta name="twitter:app:url:ipad" content="vnd.youtube://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2&amp;feature=applinks">
#     <meta name="twitter:app:name:googleplay" content="YouTube">
#     <meta name="twitter:app:id:googleplay" content="com.google.android.youtube">
#     <meta name="twitter:app:url:googleplay" content="https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2">
#       <meta name="twitter:player" content="https://www.youtube.com/embed/7B-nvXUJGQs?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk">
#       <meta name="twitter:player:width" content="1280">
#       <meta name="twitter:player:height" content="720">
#
# <style>.exp-invert-logo .hats-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_mini_gray-vflfanGkh.png);width: 65px;height: 15px;}.exp-invert-logo #header:before,.exp-invert-logo .ypc-join-family-header .logo,.exp-invert-logo #footer-logo .footer-logo-icon,.exp-invert-logo #yt-masthead #logo-container .logo,.exp-invert-logo #masthead #logo-container,.exp-invert-logo .admin-masthead-logo a,.exp-invert-logo #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small-vflHpzGZm.png);width: 100px;height: 30px;}.exp-invert-logo.inverted-hdpi #header:before,.exp-invert-logo.inverted-hdpi .ypc-join-family-header .logo,.exp-invert-logo.inverted-hdpi #footer-logo .footer-logo-icon,.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo,.exp-invert-logo.inverted-hdpi #masthead #logo-container,.exp-invert-logo.inverted-hdpi .admin-masthead-logo a,.exp-invert-logo.inverted-hdpi #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small_2x-vfl4_cFqn.png);background-size: 100px 30px;width: 100px;height: 30px;}.exp-invert-logo.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);width: 40px;height: 28px;}@media screen and (max-width: 656px) {.exp-invert-logo #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}@media only screen and (min-width: 0px) and (max-width: 498px),only screen and (min-width: 499px) and (max-width: 704px) {.exp-invert-logo.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}.exp-invert-logo #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red-vflZxcSR1.png);width: 132px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red_2x-vflOSHA_n.png);background-size: 132px 30px;width: 132px;height: 30px;}.exp-invert-logo .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red-vflovGTdz.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_2x-vflqMdgEM.png);background-size: 20px 20px;width: 20px;height: 20px;}.exp-invert-logo .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_hover-vflgV4Gv0.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo.inverted-hdpi .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_hover_2x-vflYjZHvf.png);background-size: 20px 20px;width: 20px;height: 20px;}.exp-invert-logo li.guide-section h3,.exp-invert-logo li.guide-section h3 a {color: #f00;}.exp-invert-logo a.yt-uix-button-epic-nav-item:hover,.exp-invert-logo a.yt-uix-button-epic-nav-item.selected,.exp-invert-logo a.yt-uix-button-epic-nav-item.yt-uix-button-toggl ...
# <div id="early-body"></div><div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form name="logoutForm" method="POST" action="/logout"><input type="hidden" name="action_logout" value="1"></form><div id="masthead-positioner">  <div id="ticker-content">
#
#
#   </div>
#   <div id="yt-masthead-container" class="clearfix yt-base-gutter">  <button id="a11y-skip-nav" class="skip-nav" data-target-id="main" tabindex="3">
# 略過導覽功能
#   </button>
# <div id="yt-masthead"><div class="yt-masthead-logo-container ">  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-text yt-uix-button-empty yt-uix-button-has-icon appbar-guide-toggle appbar-guide-clickable-ancestor" type="button" onclick=";return false;" id="appbar-guide-button" aria-label="導覽區" aria-controls="appbar-guide-menu"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-appbar-guide yt-sprite"></span></span></button>
#   <div id="appbar-main-guide-notification-container"></div>
# <span id="yt-masthead-logo-fragment"><a href="/" class="masthead-logo-renderer yt-uix-sessionlink      spf-link " data-sessionlink="itct=CAUQsV4iEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0"  id="logo-container" title="YouTube 首頁">  <span class="logo masthead-logo-renderer-logo yt-sprite" title="YouTube 首頁"></span>
# <span class="content-region">TW</span></a></span></div><div id="yt-masthead-signin"><a  href="//www.youtube.com/upload" class="yt-uix-button   yt-uix-sessionlink yt-uix-button-opacity yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-sessionlink="ei=Z7HEWsCONYbk4wLD64PADw&amp;feature=mhsb" id="upload-btn" title="上傳"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-material-upload yt-sprite"></span></span></a><div class="signin-container "><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary" type="button" onclick=";window.location.href=this.getAttribute(&#39;href&#39;);return false;" href="https://accounts.google.com/ServiceLogin?uilel=3&amp;hl=zh-TW&amp;service=youtube&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fhl%3Dzh-TW%26feature%3Dsign_in_button%26app%3Ddesktop%26action_handle_signin%3Dtrue%26next%3D%252Fwatch%253Fv%253D7B-nvXUJGQs%2526list%253DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%2526index%253D2" role="link"><span class="yt-uix-button-content">登入</span></button></div></div><div id="yt-masthead-content"><form id="masthead-search" class="  search-form consolidated-form  vve-check" action="/results" onsubmit="if (document.getElementById(&#39;masthead-search-term&#39;).value == &#39;&#39;) return false;" data-clicktracking="CAEQ7VAiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0" data-visibility-tracking="CAEQ7VAiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default search-btn-component search-button" type="submit" onclick="if (document.getElementById(&#39;masthead-search-term&#39;).value == &#39;&#39;) return false; document.getElementById(&#39;masthead-search&#39;).submit(); return false;;return true;" dir="ltr" tabindex="2" id="search-btn"><span class="yt-uix-button-content">搜尋</span></button><div id="masthead-search-terms" class="masthead-search-terms-border" dir="ltr"><input id="masthead-search-term" autocomplete="off"  onkeydown="if (!this.value &amp;&amp; (event.keyCode == 40 || event.keyCode == 32 || event.keyCode == 34)) {this.onkeydown = null; this.blur();}" class="search-term masthead-search-renderer-input yt-uix-form-input-bidi" name="search_query" value="" type="text" tabindex="1" placeholder="搜尋" title="搜尋" aria-label="搜尋"></div></form></div></div></div>
#     <div id="masthead-appbar-container" class="clearfix"><div id="masthead-appbar"><div id="appbar-content" class=""></div></div></div>
#
# </div><div id="masthead-positioner-height-offset"></div><div id="page-container"><div id="page" class="  watch        video-7B-nvXUJGQs clearfix"><div id="guide" class="yt-scrollbar">    <div id="appbar-guide-menu" class="appbar-menu appbar-guide-menu-layout appbar-guide-clickable-ancestor">
#     <div id="guide-container">
#       <div class="guide-module-content guide-module-loading">
#           <p class="yt-spinner ">
#         <span class="yt-spinner-img  yt-sprite" title="正在載入圖示"></span>
#
#     <span class="yt-spinner-message">
# 載入中…
#     </span>
#   </p>
#
#       </div>
#     </div>
#   </div>
#
# </div><div class="alerts-wrapper"><div id="alerts" class="content-alignment">    <div class="yt-alert yt-alert-default yt-alert-info  " id="yt-lang-alert-container">  <div class="yt-alert-icon">
#     <span class="icon master-sprite yt-sprite"></span>
#   </div>
# <div class="yt-alert-content" role="alert">    <div class="yt-alert-message" tabindex="0">
#             選擇語言。
#
#     </div>
# </div><div class="yt-alert-buttons"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" type="button" onclick=";return false;" aria-label="關閉" data-close-parent-class="yt-alert"><span class="yt-uix-button-content">關閉</span></button></div><div class="yt-alert-panel ">  <div id="yt-lang-alert-content" class="clearfix">
#     <div id="default-language-message">
#       <div class="yt-lang-alert-controls">
#         <a href="//support.google.com/youtube/answer/1738660?hl=zh-TW">瞭解詳情</a><br>
#           <a href="javascript:void(0)" onclick="yt.style.toggle('default-language-message', 'default-language-message-english'); return false;">View this message in English</a>
#       </div>
# 您目前的 YouTube 語言設為<strong>中文 (繁體)</strong>。
# 您可以<a href="javascript:void(0)" onclick="yt.www.picker.displayLang();">在下方變更這項偏好設定</a>。
#     </div>
#     <div id="default-language-message-english" class="hid">
#       <div class="yt-lang-alert-controls">
#         <a href="//support.google.com/youtube/answer/1738660?hl=en">Learn more</a><br>
#       </div>
#       You're viewing YouTube in <strong>Chinese (Taiwan)</strong>.
#         You can <a href="javascript:void(0)" onclick="yt.www.picker.displayLang();">change this preference below</a>.
#     </div>
#   </div>
# </div></div>
#
#   <div id="editor-progress-alert-container"></div>
#   <div class="yt-alert yt-alert-default yt-alert-warn hid " id="editor-progress-alert-template">  <div class="yt-alert-icon">
#     <span class="icon master-sprite yt-sprite"></span>
#   </div>
# <div class="yt-alert-content" role="alert"></div><div class="yt-alert-buttons"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" type="button" onclick=";return false;" aria-label="關閉" data-close-parent-class="yt-alert"><span class="yt-uix-button-content">關閉</span></button></div></div>
#
#     <div id="edit-confirmation-alert"></div>
#   <div class="yt-alert yt-alert-actionable yt-alert-info hid " id="edit-confirmation-alert-template">  <div class="yt-alert-icon">
#     <span class="icon master-sprite yt-sprite"></span>
#   </div>
# <div class="yt-alert-content" role="alert">    <div class="yt-alert-message" tabindex="0">
#     </div>
# </div><div class="yt-alert-buttons">  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-alert-info yt-uix-button-has-icon edit-confirmation-yes" type="button" onclick=";return false;"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-like-invert yt-sprite"></span></span><span class="yt-uix-button-content">喜歡，我要保留</span></button>
#   <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-alert-info yt-uix-button-has-icon edit-confirmation-no" type="button" onclick=";return false;"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-unlike-invert yt-sprite"></span></span><span class="yt-uix-button-content">復原</span></button>
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" type="button" onclick=";return false;" aria-label="關閉" data-close-parent-class="yt-alert"><span class="yt-uix-button-content">關閉</span></button></div></div>
#
#
#
# </div></div><div id="header"></div><div id="player" class="  content-alignment       watch-small  " role="complementary"><div id="theater-background" class="player-height"></div>  <div id="player-mole-container">
#     <div id="player-unavailable" class="    hid    player-width player-height    player-unavailable ">
#               <img class="icon meh" src="/yts/img/pixel-vfl3z5WfW.gif" data-icon="/yts/img/meh7-vflGevej7.png" alt="">
#   <div class="content">
#     <h1 id="unavailable-message" class="message">
#               無法播放這部影片。
#
#     </h1>
#     <div id="unavailable-submessage" class="submessage">
#     </div>
#   </div>
#
#
#     </div>
#
#     <div id="player-api" class="player-width player-height off-screen-target player-api" tabIndex="-1"></div>
#         <script >if (window.ytcsi) {window.ytcsi.tick("cfg", null, '');}</script>
#     <script >var ytplayer = ytplayer || {};ytplayer.config = {"url":"","args":{"ldpj":"-39","sffb":true,"oid":"SaunYYXU1EY3e842s3UsNw","innertube_api_version":"v1","apply_fade_on_midrolls":true,"watermark":",https:\/\/s.ytimg.com\/yts\/img\/watermark\/youtube_watermark-vflHX6b6E.png,https:\/\/s.ytimg.com\/yts\/img\/watermark\/youtube_hd_watermark-vflAzLcD6.png","is_listed":"1","ad_flags":"0","list":"PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk","loaderUrl":"https:\/\/www.youtube.com\/watch?v=7B-nvXUJGQs\u0026list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk\u0026index=2","t":"1","watch_xlb":"https:\/\/s.ytimg.com\/yts\/xlbbin\/watch-strings-zh_TW-vflxHFu5S.xlb","adaptive_fmts":"index=713-2064\u0026clen=18149695\u0026quality_label=720p\u0026projection_type=1\u0026fps=30\u0026url=https%3A%2F%2Fr2---sn-3cgv-un5d.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26id%3Do-AL3DDGnvYyCPcIU3bGfi-ZCvOBFOSUHGzSVvv5GdFGGg%26ei%3DZ7HEWsCONYbk4wLD64PADw%26mv%3Dm%26pl%3D20%26mt%3D1522839820%26fvip%3D2%26gir%3Dyes%26ip%3D123.193.60.175%26mn%3Dsn-3cgv-un5d%252Csn-un57sn76%26source%3Dyoutube%26mm%3D31%252C29%26sparams%3Daitags%252Cclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Ckeepalive%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv%252Cpl%252Crequiressl%252Csource%252Cexpire%26requiressl%3Dyes%26clen%3D18149695%26aitags%3D133%252C134%252C135%252C136%252C160%252C242%252C243%252C244%252C247%252C278%26lmt%3D1514962034453180%26initcwndbps%3D1185000%26key%3Dyt6%26c%3DWEB%26signature%3D5CA227702C29391EB43B1DC194303EC8890344C6.CC0371B90180F61DD32F8AF0BBAB63F95A25857A%26ipbits%3D0%26itag%3D136%26keepalive%3Dyes%26expire%3D1522861512%26mime%3Dvideo%252Fmp4%26dur%3D585.885\u0026init=0-712\u0026bitrate=2006389\u0026itag=136\u0026lmt=1514962034453180\u0026size=1280x720\u0026type=video%2Fmp4%3B+codecs%3D%22avc1.4d401f%22\u0026xtags=,eotf=bt709\u0026index=245-2151\u0026clen=27978489\u0026quality_label=720p\u0026projection_type=1\u0026fps=30\u0026url=https%3A%2F%2Fr2---sn-3cgv-un5d.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26id%3Do-AL3DDGnvYyCPcIU3bGfi-ZCvOBFOSUHGzSVvv5GdFGGg%26ei%3DZ7HEWsCONYbk4wLD64PADw%26mv%3Dm%26pl%3D20%26mt%3D1522839820%26fvip%3D2%26gir%3Dyes%26ip%3D123.193.60.175%26mn%3Dsn-3cgv-un5d%252Csn-un57sn76%26source%3Dyoutube%26mm%3D31%252C29%26sparams%3Daitags%252Cclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Ckeepalive%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv%252Cpl%252Crequiressl%252Csource%252Cexpire%26requiressl%3Dyes%26clen%3D27978489%26aitags%3D133%252C134%252C135%252C136%252C160%252C242%252C243%252C244%252C247%252C278%26lmt%3D1514964071054997%26initcwndbps%3D1185000%26key%3Dyt6%26c%3DWEB%26signature%3D418B6DB6525B2FBDBD5BE2099335DC2B6E17AED0.5529BF12D3EBAA7CFB1B6D6CC1534A850E967A7D%26ipbits%3D0%26itag%3D247%26keepalive%3Dyes%26expire%3D1522861512%26mime%3Dvideo%252Fwebm%26dur%3D585.885\u0026init=0-244\u0026bitrate=1174518\u0026itag=247\u0026lmt=1514964071054997\u0026primaries=bt709\u0026size=1280x720\u0026type=video%2Fwebm%3B+codecs%3D%22vp9%22\u0026xtags=,index=713-2064\u0026clen=10163221\u0026quality_label=480p\u0026projection_type=1\u0026fps=30\u0026url=https%3A%2F%2Fr2---sn-3cgv-un5d.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26id%3Do-AL3DDGnvYyCPcIU3bGfi-ZCvOBFOSUHGzSVvv5GdFGGg%26ei%3DZ7HEWsCONYbk4wLD64PADw%26mv%3Dm%26pl%3D20%26mt%3D1522839820%26fvip%3D2%26gir%3Dyes%26ip%3D123.193.60.175%26mn%3Dsn-3cgv-un5d%252Csn-un57sn76%26source%3Dyoutube%26mm%3D31%252C29%26sparams%3Daitags%252Cclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Ckeepalive%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv%252Cpl%252Crequiressl%252Csource%252Cexpire%26requiressl%3Dyes%26clen%3D10163221%26aitags%3D133%252C134%252C135%252C136%252C160%252C242%252C243%252C244%252C247%252C278%26lmt%3D1514962034447642%26initcwndbps%3D1185000%26key%3Dyt6%26c%3DWEB%26signature%3D92D1237FFD6FB8944E244F0D6B76FA569609DD23.688F71D0361F2941E6987C9D0AE79EB7C5358B17%26ipbits%3D0%26itag%3 ...
#
#
#     <div id="watch-queue-mole" class="video-mole mole-collapsed hid"><div id="watch-queue" class="watch-playlist player-height"><div class="main-content"><div class="watch-queue-header"><div class="watch-queue-info"><div class="watch-queue-info-icon"><span class="tv-queue-list-icon yt-sprite"></span></div><h3 class="watch-queue-title">候播清單</h3><h3 class="tv-queue-title">候播清單</h3><span class="tv-queue-details"></span></div><div class="watch-queue-control-bar control-bar-button"><div class="watch-queue-mole-info"><div class="watch-queue-control-bar-icon"><span class="watch-queue-icon yt-sprite"></span></div><div class="watch-queue-title-container"><span class="watch-queue-count"></span><span class="watch-queue-title">候播清單</span><span class="tv-queue-title">候播清單</span></div></div>  <span class="dark-overflow-action-menu">
#
#
#     <button class="flip control-bar-button yt-uix-button yt-uix-button-dark-overflow-action-menu yt-uix-button-size-default yt-uix-button-has-icon no-icon-markup yt-uix-button-empty" aria-expanded="false" type="button" aria-haspopup="true" onclick=";return false;" aria-label="候播清單操作項目" ><span class="yt-uix-button-arrow yt-sprite"></span><ul class="watch-queue-menu yt-uix-button-menu yt-uix-button-menu-dark-overflow-action-menu hid" role="menu" aria-haspopup="true"><li role="menuitem"><span class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="remove-all" onclick=";return false;" >全部移除</span></li><li role="menuitem"><span class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="disconnect" onclick=";return false;" >中斷連線</span></li></ul></button>
#   </span>
#   <div class="watch-queue-controls">
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button prev-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="上一部影片"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-prev yt-sprite"></span></span></button>
#
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button play-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="播放"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-play yt-sprite"></span></span></button>
#
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button pause-watch-queue-button yt-uix-button-opacity yt-uix-tooltip hid yt-uix-tooltip" type="button" onclick=";return false;" title="暫停"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-pause yt-sprite"></span></span></button>
#
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button next-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="下一部影片"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-next yt-sprite"></span></span></button>
#   </div>
# </div><div class="autoplay-dismiss-bar fade-out"><span class="autoplay-dismiss-title-label">即將播放下一部影片</span><span><button class="yt-uix-button yt-uix-button-size-default autoplay-dismiss-button yt-uix-tooltip" type="button" onclick=";return false;" title="停止"><span class="yt-uix-button-content">停止</span></button></span></div></div><div class="watch-queue-items-container yt-scrollbar-dark yt-scrollbar"><div class="yt-uix-scroller playlist-videos-list"><ol class="watch-queue-items-list" data-scroll-action="yt.www.watchqueue.loadThumbnails">  <p class="yt-spinner ">
#         <span class="yt-spinner-img  yt-sprite" title="正在載入圖示"></span>
#
#     <span class="yt-spinner-message">
# 載入中…
#     </span>
#   </p>
# </ol><div class="autoplay-control-container yt-uix-scroller-scroll-unit hid">  <div class="autoplay-control-bar">
#     <label class="autoplay-label" for=autoplay-toggle-id></label>
#     <label class="yt-uix-form-input-checkbox-container yt-uix-form-input-container yt-uix-form-input-paper-toggle-container  "><input class="yt-uix-form-input-checkbox" type="checkbox" id="autoplay-toggle-id"/><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-bar"></div><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-button"></div></label>
#   </div>
# </div><div class="up-next-item-container hid"></div></div></div></div>  <div class="hid">
#     <div id="watch-queue-title-msg">
# 候播清單
#     </div>
#
#     <div id="tv-queue-title-msg">候播清單</div>
#
#     <div id="watch-queue-count-msg">
# __count__/__total__
#     </div>
#
#     <div id="watch-queue-loading-template">
#       <!--
#           <p class="yt-spinner ">
#         <span class="yt-spinner-img  yt-sprite" title="正在載入圖示"></span>
#
#     <span class="yt-spinner-message">
# 載入中…
#     </span>
#   </p>
#
#       -->
#     </div>
#   </div>
# </div></div>
#     <div id="player-playlist" class="  content-alignment    watch-player-playlist  ">
#
#
#   <div id="watch-appbar-playlist" class="watch-playlist player-height">
#     <div class="main-content">
#       <div class="playlist-header">
#         <div class="playlist-header-content" data-list-author="" data-full-list-id="PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" data-list-title="爬虫基础教学 (Python Scraping 教程)" data-loop-auto-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yCGF1dG9wbGF5SIuypKjX9-mP7AE" data-shuffle-auto-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yCGF1dG9wbGF5SIuypKjX9-mP7AE" data-normal-auto-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yCGF1dG9wbGF5SIuypKjX9-mP7AE" data-shareable="True" data-initial-loop-state="false" data-loop_shuffle-auto-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yCGF1dG9wbGF5SIuypKjX9-mP7AE">
#           <div class="appbar-playlist-controls clearfix">
#
#
#     <span class="yt-uix-clickcard">
#       <span class="yt-uix-clickcard-target" data-position="bottomright" data-orientation="vertical">
#   <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-player-controls yt-uix-button-empty yt-uix-button-has-icon no-icon-markup yt-uix-playlistlike watch-playlist-like yt-uix-button-opacity yt-uix-tooltip" type="button" onclick=";return false;" id="gh-playlist-save" aria-label="儲存至播放清單" title="儲存至播放清單" data-like-label="" data-toggle-class="yt-uix-button-toggled" data-like-tooltip="儲存至播放清單" data-token="" data-unlike-label="" data-unlike-tooltip="移除" data-playlist-id="PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk"></button>
#     </span>
#       <div class="signin-clickcard yt-uix-clickcard-content">
#     <h3 class="signin-clickcard-header">登入 YouTube</h3>
#     <div class="signin-clickcard-message">
#
#     </div>
#     <a  href="https://accounts.google.com/ServiceLogin?uilel=3&amp;hl=zh-TW&amp;service=youtube&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fhl%3Dzh-TW%26feature%3D__FEATURE__%26app%3Ddesktop%26action_handle_signin%3Dtrue%26next%3D%252Fwatch%253Fv%253D7B-nvXUJGQs%2526list%253DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%2526index%253D2" class="yt-uix-button  signin-button yt-uix-sessionlink yt-uix-button-primary yt-uix-button-size-default" data-sessionlink="ei=Z7HEWsCONYbk4wLD64PADw"><span class="yt-uix-button-content">登入</span></a>
#   </div>
#
#     </span>
#
#           </div>
#           <div class="playlist-info">
#             <h3 class="playlist-title">
#                 <a href="/playlist?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class=" yt-uix-sessionlink      spf-link " data-sessionlink="ei=Z7HEWsCONYbk4wLD64PADw" >爬虫基础教学 (Python Scraping 教程)</a>
#             </h3>
#             <ul class="playlist-details">
#                 <li class="author-attribution">
#                   <a href="/channel/UCdyjiB5H8Pu7aDTNVXTTpcg" class=" yt-uix-sessionlink      spf-link " data-sessionlink="ei=Z7HEWsCONYbk4wLD64PADw" >周莫烦</a>
#                 </li>
#                 <li class="playlist-progress">
# <span id="playlist-current-index">2</span><span id="playlist-length">13 部影片</span>                </li>
#             </ul>
#           </div>
#         </div>
#
#         <div class="control-bar clearfix">
#           <div class="playlist-nav-controls">
#                   <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-player-controls yt-uix-button-empty yt-uix-button-has-icon toggle-loop yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="讓播放清單循環播放" data-button-toggle="true"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-appbar-autoplay yt-sprite"></span></span></button>
#
#
#       <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-player-controls yt-uix-button-empty yt-uix-button-has-icon shuffle-playlist yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="隨機播放" data-button-toggle="true"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-appbar-shuffle-video-list yt-sprite"></span></span></button>
#
#
#           </div>
#
#           <div class="playlist-behavior-controls">
#
#               <a  href="/watch?v=DQdeWX6-Uy8&amp;index=1&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class="yt-uix-button  hid prev-playlist-list-item yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip-masked spf-link  yt-uix-button-player-controls yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-normal-prev-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX3ByZXZIi7KkqNf36Y_sAQ" data-shuffle-prev-clicktracking="" data-loop_shuffle-prev-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX3ByZXZIi7KkqNf36Y_sAQ" data-loop-prev-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX3ByZXZIi7KkqNf36Y_sAQ" title="上一部影片"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-appbar-play-prev yt-sprite"></span></span></a>
#
#
#               <a  href="/watch?v=KLq0W1wUVmw&amp;index=3&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class="yt-uix-button  hid next-playlist-list-item yt-uix-button-opacity yt-uix-tooltip spf-link  yt-uix-button-player-controls yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-normal-next-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX25leHRIi7KkqNf36Y_sAQ" data-loop_shuffle-next-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX25leHRIi7KkqNf36Y_sAQ" data-shuffle-next-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX25leHRIi7KkqNf36Y_sAQ" data-loop-next-clicktracking="CBQQ0TkiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0yB2JmX25leHRIi7KkqNf36Y_sAQ" title="下一部影片"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-appbar-play-next yt-sprite"></span></span></a>
#
#           </div>
#         </div>
#       </div>
#
#       <div class="playlist-videos-container yt-scrollbar-dark yt-scrollbar">
#         <ol id="playlist-autoscroll-list" class="playlist-videos-list yt-uix-scroller yt-viewport" data-scroll-action="yt.www.watch.lists.loadThumbnails">
#                 <li class="yt-uix-scroller-scroll-unit  vve-check" data-video-title="#1 Why? (爬虫 scraping 基础教学/教程 Tutorial)" data-innertube-clicktracking="CCMQyCAYACITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" data-video-username="周莫烦" data-index="0" data-video-id="DQdeWX6-Uy8" data-thumbnail-url="https://i.ytimg.com/vi/DQdeWX6-Uy8/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLBrAFy9Ks6Ou9FwmCIyy52U3DUriw">
#     <span class="index">
#         1
#     </span>
#       <a href="/watch?v=DQdeWX6-Uy8&amp;index=1&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class=" spf-link  playlist-video clearfix  yt-uix-sessionlink      spf-link " data-sessionlink="itct=CCMQyCAYACITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" >
#       <span class="video-thumb  yt-thumb yt-thumb-72"
#     >
#     <span class="yt-thumb-default">
#       <span class="yt-thumb-clip">
#
#   <img onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" aria-hidden="true" src="https://i.ytimg.com/vi/DQdeWX6-Uy8/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLBrAFy9Ks6Ou9FwmCIyy52U3DUriw" alt="" width="72" data-ytimg="1" >
#
#         <span class="vertical-align"></span>
#       </span>
#     </span>
#   </span>
#
#     <div class="playlist-video-description">
#       <h4 class="yt-ui-ellipsis yt-ui-ellipsis-2">
#           #1 Why? (爬虫 scraping 基础教学/教程 Tutorial)
#       </h4>
#         <span class="video-uploader-byline">
#           <span class="" >周莫烦</span>
#         </span>
#     </div>
#   </a>
#
#   </li>
#
#                 <li class="yt-uix-scroller-scroll-unit  vve-check currently-playing" data-video-title="#1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)" data-innertube-clicktracking="CCIQyCAYASITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" data-video-username="周莫烦" data-index="1" data-video-id="7B-nvXUJGQs" data-thumbnail-url="https://i.ytimg.com/vi/7B-nvXUJGQs/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLBnMDmfHO3zoVWQ5EOhkjMBPpmZPw">
#     <span class="index">
#         ▶
#     </span>
#       <a href="/watch?v=7B-nvXUJGQs&amp;index=2&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class=" spf-link  playlist-video clearfix  yt-uix-sessionlink      spf-link " data-sessionlink="itct=CCIQyCAYASITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" >
#       <span class="video-thumb  yt-thumb yt-thumb-72"
#     >
#     <span class="yt-thumb-default">
#       <span class="yt-thumb-clip">
#
#   <img onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" aria-hidden="true" src="https://i.ytimg.com/vi/7B-nvXUJGQs/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLBnMDmfHO3zoVWQ5EOhkjMBPpmZPw" alt="" width="72" data-ytimg="1" >
#
#         <span class="vertical-align"></span>
#       </span>
#     </span>
#   </span>
#
#     <div class="playlist-video-description">
#       <h4 class="yt-ui-ellipsis yt-ui-ellipsis-2">
#           #1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial)
#       </h4>
#         <span class="video-uploader-byline">
#           <span class="" >周莫烦</span>
#         </span>
#     </div>
#   </a>
#
#   </li>
#
#                 <li class="yt-uix-scroller-scroll-unit  vve-check" data-video-title="#2.1 BeautifulSoup 解析网页: 基础 (爬虫 scraping 基础教学/教程 Tutorial)" data-innertube-clicktracking="CCEQyCAYAiITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" data-video-username="周莫烦" data-index="2" data-video-id="KLq0W1wUVmw" data-thumbnail-url="https://i.ytimg.com/vi/KLq0W1wUVmw/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLBrn5ZMPsE0deFvYOHXXfqMZMQrig">
#     <span class="index">
#         3
#     </span>
#       <a href="/watch?v=KLq0W1wUVmw&amp;index=3&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class=" spf-link  playlist-video clearfix  yt-uix-sessionlink      spf-link " data-sessionlink="itct=CCEQyCAYAiITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" >
#       <span class="video-thumb  yt-thumb yt-thumb-72"
#     >
#     <span class="yt-thumb-default">
#       <span class="yt-thumb-clip">
#
#   <img onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" aria-hidden="true" src="https://i.ytimg.com/vi/KLq0W1wUVmw/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLBrn5ZMPsE0deFvYOHXXfqMZMQrig" alt="" width="72" data-ytimg="1" >
#
#         <span class="vertical-align"></span>
#       </span>
#     </span>
#   </span>
#
#     <div class="playlist-video-description">
#       <h4 class="yt-ui-ellipsis yt-ui-ellipsis-2">
#           #2.1 BeautifulSoup 解析网页: 基础 (爬虫 scraping 基础教学/教程 Tutorial)
#       </h4>
#         <span class="video-uploader-byline">
#           <span class="" >周莫烦</span>
#         </span>
#     </div>
#   </a>
#
#   </li>
#
#                 <li class="yt-uix-scroller-scroll-unit  vve-check" data-video-title="#2.2 BeautifulSoup 解析网页: CSS (爬虫 scraping 基础教学/教程 Tutorial)" data-innertube-clicktracking="CCAQyCAYAyITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" data-video-username="周莫烦" data-index="3" data-video-id="SiIwSAIC458" data-thumbnail-url="https://i.ytimg.com/vi/SiIwSAIC458/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLDXDGZN1h4AfnwQYn8U8_PKUy6vYQ">
#     <span class="index">
#         4
#     </span>
#       <a href="/watch?v=SiIwSAIC458&amp;index=4&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk" class=" spf-link  playlist-video clearfix  yt-uix-sessionlink      spf-link " data-sessionlink="itct=CCAQyCAYAyITCIDe_N-8oNoCFQbyWAodw_UA-Cj4HTIDQkZhSIuypKjX9-mP7AE" >
#       <span class="video-thumb  yt-thumb yt-thumb-72"
#     >
#     <span class="yt-thumb-default">
#       <span class="yt-thumb-clip">
#
#   <img onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" aria-hidden="true" src="https://i.ytimg.com/vi/SiIwSAIC458/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLDXDGZN1h4AfnwQYn8U8_PKUy6vYQ" alt="" width="72" data-ytimg="1" >
#
#         <span class="vertical-align"></span>
#       </span>
#     </span>
#   </span>
#
#     <div class="playlist-video-description">
#       <h4 class="yt-ui-ellipsis yt-ui-ellipsis-2">
#           #2.2 BeautifulSoup 解析网页: CSS (爬虫 scraping 基础教学/教程 Tutorial)
#       </h4>
#         <span class="video-uploader-byline">
#           <span class="" >周莫烦</span>
#         </span>
#     </div>
#   </a>
#
#   </li>
#
# ...
#           'BG_IU': "\/\/www.google.com\/js\/bg\/4mrRnEPnWo81qWPG8_xcGP85HCscbg1O2YUrIewxQYY.js",
#
#         'METADATA_LANGUAGE': 'zh',
#
#
#         'COMMENTS_TOKEN': "EkwSCzdCLW52WFVKR1FzIiJQTFhPNDV0c0I5NWNJdVhFZ1YtbXZZV1JkX2hWQzQzQWtrOAHAAQDIAQDgAQGiAg0o____________AUAAGAY%3D",
#
#       'GET_PLAYER_EVENT_ID': "Z7HEWsCONYbk4wLD64PADw",
#       'HL_LOCALE': "zh_TW",
#       'TTS_URL': "",
#       'JS_DELAY_LOAD': 0,
#       'LIST_AUTO_PLAY_VALUE': 1,
#       'SHUFFLE_VALUE': 0,
#       'SKIP_RELATED_ADS': false,
#       'SKIP_TO_NEXT_VIDEO': false,
#       'CONVERSION_CONFIG_DICT': {},
#       'RESOLUTION_TRACKING_ENABLED': false,
#       'WATCH_LEGAL_TEXT_ENABLE_AUTOSCROLL': false,
#       'ADS_DATA': {"show_afc":false,"afc_vars":{"language":"zh","video_doc_id":"yt_7B-nvXUJGQs","eids":[],"core_dbp":"ChZyRkh3amtCWEFXaFlYZTM2LXk5SzV3EAEgASgA","format":"300x250_as","ad_client":"ca-pub-6219811747049371","pucrd":"CgYIABAAGAB4Ag","loeid":"9422596,9471235,23705778,23717314,23728036,23729840,23729847,23731256,23732788,23734856","targeting":"","ad_host":"ca-host-pub-4601203457616636","lact":"-1","ad_block":"2","ad_type":"image","ad_host_tier_id":"14323591","tag_for_child_directed_treatment":"","alternate_ad_url":"https:\/\/www.youtube.com\/ad_frame?id=watch-channel-brand-div","ad_channel":"0854550287+Vertical_12+Vertical_211+Vertical_343+Vertical_36+Vertical_5+Vertical_613+Vertical_77+afc_on_page+afv_user_id_dyjiB5H8Pu7aDTNVXTTpcg+afv_user_morvanzhou+ivp+yt_cid_38145806+yt_mpvid_5JsUyFubi5rrFz09+yt_no_360+yt_no_ap+yt_no_cp+yt_no_wa+ytdevice_1+ytdevicever_1.20180403+ytel_detailpage+ytps_default"},"afv_vars":{"google_yt_pt":"APb3F2_zCTvXY5O4tw_O1-Ypet62yctRNwh3QO6JwYI64zBwSh2NfEk2wKd0xYMeSMmHwiWCAftLTw6smaNEpXIyRXXc8s5ZteLA-ZTp6km_mxXDP3nDBs8tUy9ZQcx-FhB9OsETdy0LSpBavHba","google_tag_for_child_directed_treatment":"","google_eids":[],"google_ad_height":"250","google_loeid":"9422596,9471235,23705778,23717314,23728036,23729840,23729847,23731256,23732788,23734856","google_ad_block":"2","google_page_url":"http:\/\/www.youtube.com\/video\/7B-nvXUJGQs","google_targeting":"","google_cust_gender":"","google_ad_client":"ca-pub-6219811747049371","google_scs":"","google_language":"zh","google_cust_age":"","google_ad_format":"300x250_as","google_lact":"-1","google_core_dbp":"ChZyRkh3amtCWEFXaFlYZTM2LXk5SzV3EAEgASgA","google_ad_host_tier_id":"14323591","google_alternate_ad_url":"https:\/\/www.youtube.com\/ad_frame?id=watch-channel-brand-div","google_ad_channel":"0854550288+Vertical_12+Vertical_211+Vertical_343+Vertical_36+Vertical_5+Vertical_613+Vertical_77+afv_user_id_dyjiB5H8Pu7aDTNVXTTpcg+afv_user_morvanzhou+ivp+yt_cid_38145806+yt_mpvid_5JsUyFubi5rrFz09+yt_no_360+yt_no_ap+yt_no_cp+yt_no_wa+ytdevice_1+ytdevicever_1.20180403+ytel_detailpage+ytps_default","google_pucrd":"CgYIABAAGAB4Ag","google_ad_type":"image","google_ad_host":"ca-host-pub-4601203457616636","google_video_doc_id":"yt_7B-nvXUJGQs"},"pyv_ad_tag":{"tag":"https:\/\/googleads.g.doubleclick.net\/pagead\/lopri?ad_block=3\u0026ad_type=text\u0026adk=511001906\u0026channel=PyvWatchInRelated%2BPyvWatchNoAdX%2BPyvYTWatch%2BYtLoPri%2Bafv_user_id_dyjiB5H8Pu7aDTNVXTTpcg%2Bafv_user_morvanzhou%2Bnon_lpw%2Bpw%2Byt_cid_38145806%2Byt_mpvid_5JsUyFubi5rrFz09%2Byt_no_ap%2Bytdevice_1%2Bytdevicever_1.20180403\u0026client=ca-pub-6219811747049371\u0026correlator=1522839911998\u0026dbp=ChZyRkh3amtCWEFXaFlYZTM2LXk5SzV3EAEgASgA\u0026ea=0\u0026eae=2\u0026hl=zh\u0026host=ca-host-pub-4601203457616636\u0026ht_id=14323591\u0026isw=0\u0026ish=0\u0026lact=-1\u0026loc=EMPTY\u0026loeid=9422596,9471235,23705778,23717314,23728036,23729840,23729847,23731256,23732788,23734856\u0026num_ads=1\u0026output=js\u0026pucrd=CgYIABAAGAB4Ag\u0026pyv=1\u0026top=https%3A\/\/www.youtube.com\/watch%3Fv%3D7B-nvXUJGQs%26app%3Ddesktop\u0026url=http%3A%2F%2Fwww.youtube.com%2Fvideo%2F7B-nvXUJGQs\u0026video_doc_id=yt_7B-nvXUJGQs\u0026ytdevicever=ytdevicever_1.20180403\u0026yt_pt=APb3F2_wa4gvxxN7ZNuW_2eej0SuR4OZL4Rdcz11NP0K7SRX6RMbCeFPkAoHONNA850E-0T74smwEBo6mDQumnlus5IoiGsQidVyPivnqgFbx2rEMYX3KOwCa25QykPV0bUfpbKRHkZGTHNpI0G9"},"use_gut":true,"show_instream":true,"check_status":false,"show_afv":true,"show_pyv":true,"gut_vars":{"tag":"\/4061\/ytpwatch"}},
#       'PLAYBACK_ID': "AAVpA8wBenicdhvN",
#       'IS_DISTILLER': true,
#       'SHARE_CAPTION': null,
#       'SHARE_REFERER': "",
#       'PLAYLIST_INDEX': 1
#     });
#
#       yt.pushConfigArray('TIMING_WAIT', 'parn');
#
#     yt.setMsg({
#       'EDITOR_AJAX_REQUEST_FAILED': "嘗試從伺服器取得資料時發生錯誤。請再試一次，或重新載入網頁。",
#       'EDITOR_AJAX_REQUEST_503': "目前無法使用這項功能，請稍後再試一次。",
#         'CC_ADD_TRANSCRIPT_TITLE': "新增翻譯字幕",
#       'LOADING': "載入中…"    });
#
#
#
#
#
#
#
#
#
#
#
#
#       yt.setConfig({
#     'GUIDED_HELP_LOCALE': "zh_TW",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
#
#   </script>
#
#
# <script>yt.setConfig({APIARY_HOST: "",INNERTUBE_CONTEXT_CLIENT_NAME: 1,GAPI_HINT_PARAMS: "m;\/_\/scs\/abc-static\/_\/js\/k=gapi.gapi.en.wjAGE-AVlTo.O\/m=__features__\/am=AAE\/rt=j\/d=1\/rs=AHpOoo-gY863zTybf8wCUIW8gIU8UfC49g",INNERTUBE_API_VERSION: "v1",INNERTUBE_API_KEY: "AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8",INNERTUBE_CONTEXT_CLIENT_VERSION: "1.20180403",XHR_APIARY_HOST: "youtubei.youtube.com",APIARY_HOST_FIRSTPARTY: "",'VISITOR_DATA': "CgtITDc0cm1ldDV3RQ%3D%3D",'DELEGATED_SESSION_ID': null,'GAPI_HOST': "https:\/\/apis.google.com",'GAPI_LOCALE': "zh_TW",'INNERTUBE_CONTEXT_HL': "zh-TW",'INNERTUBE_CONTEXT_GL': "TW",'XHR_APIARY_HOST': "youtubei.youtube.com"});yt.setConfig({'ROOT_VE_CHILDREN': ["CAEQ7VAiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0","CAIQpmEiEwiA3vzfvKDaAhUG8lgKHcP1APgo-B0"],});yt.setConfig({'PAGE_NAME': "watch",'LOGGED_IN': false,'SESSION_INDEX': null,'VALID_SESSION_TEMPDATA_DOMAINS': ["www.youtube.com","gaming.youtube.com"],'PARENT_TRACKING_PARAMS': "",'FORMATS_FILE_SIZE_JS': ["%s B","%s KB","%s MB","%s GB","%s TB"],'ONE_PICK_URL': "",'GOOGLEPLUS_HOST': "https:\/\/plus.google.com",'PAGEFRAME_JS': "\/yts\/jsbin\/www-pageframe-vflheBcDC\/www-pageframe.js",'GAPI_LOADER_URL': "\/yts\/jsbin\/www-gapi-loader-vfl4N1E0u\/www-gapi-loader.js",'JS_COMMON_MODULE': "\/yts\/jsbin\/www-en_US-vfl-VJqWc\/common.js",'PAGE_FRAME_DELAYLOADED_CSS': "\/yts\/cssbin\/www-pageframedelayloaded-vflNXOrSa.css",'EXPERIMENT_FLAGS': {"lact_local_listeners":true,"log_web_screen_end":true,"desktop_polymer_video_masthead_session_tempdata_ttl":30,"enable_logging_directives_desktop":true,"botguard_periodic_refresh":true,"cancel_pending_navs":true,"watch_next_pause_autoplay_lact_sec":4500,"desktop_pyv_on_watch_override_lact":true,"service_worker_push_prompt_cap":-1,"live_chat_replay":true,"autoplay_pause_sampling_fraction":0.0,"log_window_onerror_fraction":0.1,"service_worker_push_home_page_prompt":true,"desktop_pyv_on_watch_via_valor":true,"log_vis_on_tab_change":true,"desktop_polymer_video_masthead_mute_ad_support":true,"enable_youtubei_innertube":true,"custom_emoji_creator":true,"player_swfcfg_cleanup":true,"desktop_polymer":true,"enable_gaming_new_logo":true,"same_domain_static_resources_desktop":true,"optimistically_create_transport_client":true,"desktop_pyv_on_watch_missing_params":true,"desktop_polymer_video_masthead_wta_support":true,"autoescape_tempdata_url":true,"log_web_meta_interval_ms":0,"web_always_load_chat_support":true,"live_chat_viewer_blocks_show_ui":true,"enable_watch_next_pause_autoplay_lact":true,"interaction_logging_on_gel_web":true,"web_logging_max_batch":100,"web_gel_lact":true,"desktop_polymer_video_masthead_always_use_responsive_iframe":true,"live_chat_replay_milliqps_threshold":5000,"desktop_notification_high_priority_ignore_push":true,"chat_smoothing_animations":84,"service_worker_push_prompt_delay_ms":3888000000,"custom_emoji_main_app":true,"live_chat_inline_moderation":true,"consent_url_override":"","live_chat_top_chat_window_length_sec":4,"enable_firefox_push_notifications":true,"enable_desktop_polymer_video_masthead_upgrade":true,"custom_emoji_desktop":true,"enable_webcam_streams":true,"service_worker_push_prompt_delay_microseconds":3888000000000,"remove_web_visibility_batching":true,"retry_web_logging_batches":true,"enable_afv_div_reset_in_kevlar":true,"enable_gel_web_client_event_id":true,"sponsors_whitelist_creator":true,"interaction_click_on_gel_web":true,"service_worker_enabled":true,"autoplay_pause_by_lact_sampling_fraction":0.0,"debug_forced_promo_id":"","service_worker_push_watch_page_prompt":true,"enable_desktop_polymer_video_masthead":true,"custom_emoji_super_chat":true,"service_worker_scope":"\/","custom_emoji_legacy":true,"app_settings_snapshot_is_logging_enabled":true,"live_chat_message_sampling_rate":4.0,"very_optimistically_create_gel_client":true,"live_chat_replay_viewer_disclosure":true,"service_worker_push_home_only":true,"enable_playlist_visibility":true,"enable_server_side_search_pyv":true,"html5_serversid ...
#     'GUIDED_HELP_LOCALE': "zh_TW",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
# yt.setConfig('SPF_SEARCH_BOX', true);yt.setMsg({'ADDTO_CREATE_NEW_PLAYLIST': "建立新的播放清單\n",'ADDTO_CREATE_PLAYLIST_DYNAMIC_TITLE': "  $dynamic_title_placeholder (新建)\n",'ADDTO_WATCH_LATER': "Watch later",'ADDTO_WATCH_LATER_ADDED': "已新增",'ADDTO_WATCH_LATER_ERROR': "錯誤",'ADDTO_WATCH_QUEUE': "Watch Queue",'ADDTO_WATCH_QUEUE_ADDED': "已新增",'ADDTO_WATCH_QUEUE_ERROR': "錯誤",'ADDTO_TV_QUEUE': "Queue",'ADS_INSTREAM_FIRST_PLAY': "正在播放影片廣告。",'ADS_INSTREAM_SKIPPABLE': "您可以略過影片廣告。",'ADS_OVERLAY_IMPRESSION': "廣告放送完畢。",'MASTHEAD_NOTIFICATIONS_LABEL': {"other": "# \u5247\u672a\u8b80\u7684\u901a\u77e5\u3002", "case1": "1 \u5247\u672a\u8b80\u7684\u901a\u77e5\u3002", "case0": "\u6c92\u6709\u672a\u8b80\u7684\u901a\u77e5\u3002"},'MASTHEAD_NOTIFICATIONS_COUNT_99PLUS': "99+",'MDX_AUTOPLAY_OFF': '已停用自動播放功能','MDX_AUTOPLAY_ON': '已啟用自動播放功能'});  yt.setConfig('FEED_PRIVACY_CSS_URL', "\/yts\/cssbin\/www-feedprivacydialog-vflP1Pnju.css");
#   yt.setConfig('FEED_PRIVACY_LIGHTBOX_ENABLED', true);
# yt.setConfig({'SBOX_JS_URL': "\/yts\/jsbin\/www-searchbox-legacy-vflFal7-i\/www-searchbox-legacy.js",'SBOX_SETTINGS': {"PQ":"","SESSION_INDEX":null,"REQUEST_LANGUAGE":"zh-TW","IS_FUSION":false,"REQUEST_DOMAIN":"tw","SUGG_EXP_ID":"","PSUGGEST_TOKEN":null,"HAS_ON_SCREEN_KEYBOARD":false},'SBOX_LABELS': {"SUGGESTION_DISMISS_LABEL":"移除","SUGGESTION_DISMISSED_LABEL":"已移除查詢建議"}});  yt.setConfig({
#     'YPC_LOADER_JS': "\/yts\/jsbin\/www-ypc-vflhkcaBm\/www-ypc.js",
#     'YPC_LOADER_CSS': "\/yts\/cssbin\/www-ypc-vfluXUBpe.css",
#     'YPC_SIGNIN_URL': "https:\/\/accounts.google.com\/ServiceLogin?uilel=3\u0026hl=zh-TW\u0026service=youtube\u0026passive=true\u0026continue=http%3A%2F%2Fwww.youtube.com%2Fsignin%3Fhl%3Dzh-TW%26app%3Ddesktop%26action_handle_signin%3Dtrue%26next%3D%252F",
#     'DBLCLK_ADVERTISER_ID': "2542116",
#     'DBLCLK_YPC_ACTIVITY_GROUP': "youtu444",
#     'SUBSCRIPTION_URL': "\/subscription_ajax",
#     'YPC_SWITCH_URL': "\/signin?feature=purchases\u0026skip_identity_prompt=True\u0026action_handle_signin=true\u0026next=%2F",
#     'YPC_GB_LANGUAGE': "zh_TW",
#     'YPC_MB_URL': "https:\/\/payments.youtube.com\/payments\/v4\/js\/integrator.js?ss=md",
#     'YPC_TRANSACTION_URL': "\/transaction_handler",
#     'YPC_SUBSCRIPTION_URL': "\/ypc_subscription_ajax",
#     'YPC_POST_PURCHASE_URL': "\/ypc_post_purchase_ajax",
#     'YTR_FAMILY_CREATION_URL': "https:\/\/families.google.com\/webcreation?usegapi=1",
#     'YTO_GTM_DATA': {'event': 'purchased', 'purchaseStatus': 'success'},
#     'YTO_GTM_1_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '1'},
#     'YTO_GTM_2_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '2'}
#   });
#   yt.setMsg({
#     'YPC_OFFER_OVERLAY': "  \n",
#     'YPC_UNSUBSCRIBE_OVERLAY': "  \n"
#   });
#   yt.setConfig('GOOGLE_HELP_CONTEXT', "watch");
# ytcsi.info('st', 357);ytcfg.set({"CSI_SERVICE_NAME":"youtube","TIMING_INFO":{"yt_ad_pr":1,"yt_ad_an":"afv,dclk","GetWatchNext_rid":"0x83250523923f8961","yt_li":"0","yt_pl":1,"yt_lt":"cold","yt_ad":1,"c":"WEB","cver":"1.20180403","GetPlayer_rid":"0x83250523923f8961"}});;ytcfg.set({"TIMING_ACTION":"watch","CSI_VIEWPORT":true});;  yt.setConfig({
#       'XSRF_TOKEN': "",
#       'XSRF_FIELD_NAME': "session_token",
#
#       'XSRF_REDIRECT_TOKEN': "8_mmAkO1D7m95VgMryDRBifG4Wl8MTUyMjkyNjMxMkAxNTIyODM5OTEy"  });
# yt.setConfig('ID_TOKEN', null);window.ytcfg.set('SERVICE_WORKER_KILLSWITCH', false);  yt.setConfig('THUMB_DELAY_LOAD_BUFFER', 0);
# if (window.ytcsi) {window.ytcsi.tick("jl", null, '');}</script>
# </body></html>

# %%
import re
res = re.findall(r"<title>(.+?)</title>", html)
print("\nPage title is: ", res[0])

# Page title is:  Scraping tutorial 1 | 莫烦Python
# Out:
# Page title is:  #1.1 了解网页结构 (爬虫 scraping 基础教学/教程 Tutorial) - YouTube

# %%
res = re.findall(r"<p>(.*?)</p>", html, flags=re.DOTALL)    # re.DOTALL if multi line
print("\nPage paragraph is: ", res[0])

# Page paragraph is:
#  这是一个在 <a href="https://morvanzhou.github.io/">莫烦Python</a>
#  <a href="https://morvanzhou.github.io/tutorials/scraping">爬虫教程</a> 中的简单测试.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c9f74839a49c> in <module>()
#       1 res = re.findall(r"<p>(.*?)</p>", html, flags=re.DOTALL)    # re.DOTALL if multi line
# ----> 2 print("\nPage paragraph is: ", res[0])
#       3
#       4 # Page paragraph is:
#       5 #  这是一个在 <a href="https://morvanzhou.github.io/">莫烦Python</a>
#
# IndexError: list index out of range

# %%
res = re.findall(r'href="(.*?)"', html)
print("\nAll links: ", res)
# All links:
['https://morvanzhou.github.io/static/img/description/tab_icon.png',
'https://morvanzhou.github.io/',
'https://morvanzhou.github.io/tutorials/scraping']
# Out:
# All links:  ['/yts/cssbin/www-core-vflx7D8A3.css', '/yts/cssbin/player-vflxUKlL0/www-player.css', '/yts/cssbin/www-pageframe-vflBE-miK.css', 'https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2', 'https://m.youtube.com/watch?v=7B-nvXUJGQs', 'https://m.youtube.com/watch?v=7B-nvXUJGQs', '/manifest.json', 'https://youtu.be/7B-nvXUJGQs?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', 'https://www.youtube.com/opensearch?locale=zh_TW', 'https://s.ytimg.com/yts/img/favicon-vfl8qSV2F.ico', '/yts/img/favicon_32-vflOogEID.png', '/yts/img/favicon_48-vflVjB_Qk.png', '/yts/img/favicon_96-vflW9Ec0w.png', '/yts/img/favicon_144-vfliLAfaB.png', 'android-app://com.google.android.youtube/http/www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2', 'ios-app://544007664/vnd.youtube/www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2', 'http://www.youtube.com/oembed?url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D7B-nvXUJGQs%26list%3DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%26index%3D2&amp;format=json', 'http://www.youtube.com/oembed?url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D7B-nvXUJGQs%26list%3DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%26index%3D2&amp;format=xml', '/', '//www.youtube.com/upload', 'https://accounts.google.com/ServiceLogin?uilel=3&amp;hl=zh-TW&amp;service=youtube&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fhl%3Dzh-TW%26feature%3Dsign_in_button%26app%3Ddesktop%26action_handle_signin%3Dtrue%26next%3D%252Fwatch%253Fv%253D7B-nvXUJGQs%2526list%253DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%2526index%253D2', '//support.google.com/youtube/answer/1738660?hl=zh-TW', 'javascript:void(0)', 'javascript:void(0)', '//support.google.com/youtube/answer/1738660?hl=en', 'javascript:void(0)', 'https://accounts.google.com/ServiceLogin?uilel=3&amp;hl=zh-TW&amp;service=youtube&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fhl%3Dzh-TW%26feature%3D__FEATURE__%26app%3Ddesktop%26action_handle_signin%3Dtrue%26next%3D%252Fwatch%253Fv%253D7B-nvXUJGQs%2526list%253DPLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk%2526index%253D2', '/playlist?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/channel/UCdyjiB5H8Pu7aDTNVXTTpcg', '/watch?v=DQdeWX6-Uy8&amp;index=1&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=KLq0W1wUVmw&amp;index=3&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=DQdeWX6-Uy8&amp;index=1&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=7B-nvXUJGQs&amp;index=2&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=KLq0W1wUVmw&amp;index=3&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=SiIwSAIC458&amp;index=4&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=OfmmsxVSP0o&amp;index=5&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=dSypElTfcFM&amp;index=6&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=L6ewlStcEzI&amp;index=7&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=ScT0FJdHc5o&amp;index=8&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=rwI7bFXdOsk&amp;index=9&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=QRJdEdgpTos&amp;index=10&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=Wa2K7sB7BZE&amp;index=11&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=roTwhVIHkAo&amp;index=12&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/watch?v=0Uug1fDa8nw&amp;index=13&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', 'https://www.youtube.com/watch?v=7B-nvXUJGQs&amp;list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk&amp;index=2', 'http://www.youtube.com/user/MorvanZhou', 'https://plus.google.com/113672387420728553702', 'https://i.ytimg.com/vi/7B-nvXUJGQs/maxresdefault.jpg', 'https://i.ytimg.com/vi/7B-nvXUJGQs/maxresdefault.jpg', 'https://www.youtube.com/embed/7B-nvXUJGQs?list=PLXO45tsB95cIuXEgV-mvYWRd_hVC43Akk', '/user/MorvanZhou', '/channel/UCdyjiB5H8Pu7aDTNVXTTpcg', 'https://accounts.google.com/ServiceLogin?uilel=3&amp;hl=zh-TW&amp;service=youtube&amp; ...
# ['https://morvanzhou.github.io/static/img/description/tab_icon.png',
#  'https://morvanzhou.github.io/',
#  'https://morvanzhou.github.io/tutorials/scraping']

# %%
# Out:
#   File "<ipython-input-6-750557ee991d>", line 1
#     pip3 install beautifulsoup4
#                ^
# SyntaxError: invalid syntax
